# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('overall-marks.xlsx')
df.head()
# Out:
#    S.No                Full Name                    Email  Attendance - 10  \
# 0    28       Muhammad Faiz Raza  faiz.raza.dec@gmail.com         9.459459
# 1     2             WAHEED IQBAL      wafaw1619@gmail.com         9.729730
# 2    18        Soban Saqib Khan     sobansaqib2@gmail.com         9.459459
# 3    42  Muneeb-ur-Rehman Faheem     25010110@lums.edu.pk        10.000000
# 4     3   Mohammad Farrukh Tahir  farrukhtahir5@gmail.com        10.000000
#
#    Lab - 30  Project - 60      Total
# 0   29.3125          60.0  98.771959
# 1   28.5000          55.0  93.229730
# 2   26.4375          44.0  79.896959
# 3   24.5625          44.5  79.062500
# 4   28.8750          39.4  78.275000

# %%
try:
    df = df.sort_values(by="Project - 60", ascending=False).reset_index(drop=True)
except KeyError:
    print("Column 'Attendance - 10' not found in the DataFrame.")
except TypeError:
    print("Error sorting by non-numeric column 'Attendance - 10'.")
df
# Out:
#     S.No                  Full Name                               Email  \
# 0     28         Muhammad Faiz Raza             faiz.raza.dec@gmail.com
# 1      2               WAHEED IQBAL                 wafaw1619@gmail.com
# 2     21    Muhammad Huzaifah Imran          huzaifahimran541@gmail.com
# 3     53               Ammara Saeed        ammarasaeed2020@namal.edu.pk
# 4     42    Muneeb-ur-Rehman Faheem                25010110@lums.edu.pk
# 5     18          Soban Saqib Khan                sobansaqib2@gmail.com
# 6      5         Aamir Khan Maarofi                kaamir6600@gmail.com
# 7     30              Ibrahim Saad             saadibrahim249@gmail.com
# 8     31                 Hamza Atiq               hamzaatiq34@gmail.com
# 9     19               Hassan Javed             hassanj.maths@gmail.com
# 10    22          Muhammad Huzaifah              mhuzaifah623@gmail.com
# 11    44                 Asif Ullah                std102372@uop.edu.pk
# ...
